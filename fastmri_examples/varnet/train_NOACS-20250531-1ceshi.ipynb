# %%
import numpy as np

# %%
cd /data0/wangyuwan/fastmri--varnet/JNU_SZTU_PROJECT/ZGRAPPA_model_work/fastMRI/fastmri_examples/varnet/varnet
# Out:
# /data0/wangyuwan/fastmri--varnet/JNU_SZTU_PROJECT/ZGRAPPA_model_work/fastMRI/fastmri_examples/varnet/varnet

# %%
ceshi = np.load('batch.real_masked_kspace.npy')
ACS = np.load('ACS_kspace.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 ceshi = np.load('batch.real_masked_kspace.npy')
#       2 ACS = np.load('ACS_kspace.npy')
#
# File ~/.local/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'batch.real_masked_kspace.npy'

# %%
ceshi.shape
# Out:
# (1, 16, 384, 384)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.log(abs(ceshi[0,0,192-10:192+10,192-10:192+10]))+1e-10)
# Out:
# /tmp/ipykernel_2521596/3969556983.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(abs(ceshi[0,0,192-10:192+10,192-10:192+10]))+1e-10)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.log(abs(ACS[0,0]))+1e-10)
# Out:
# /tmp/ipykernel_2521596/2172903116.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(abs(ACS[0,0]))+1e-10)

# %%
import fastmri

# %%
def ifft2c(x, axes=(- 2, - 1)):
    '''
    Centered ifft
    Note: fft2 applies fft to last 2 axes by default
    :param x: 2D onwards. e.g: if its 3d, x.shape = (n,row,col). 4d:x.shape = (n,slice,row,col)
    :return:
    '''
    #axes = (-2, -1)  # get last 2 axes
    res = fftshift(ifft2d(ifftshift(x), axes=axes, norm="ortho"))
    return res

# %%
from numpy.fft import fft, fft2 as fft2d, ifft2 as ifft2d, ifft, ifftshift, fftshift

# %%
i = ifft2c(ceshi)

# %%
plt.imshow(abs(i[0,0]))

# %%
AI = ifft2c(ACS)

# %%
plt.imshow(abs(AI[0,0]))
